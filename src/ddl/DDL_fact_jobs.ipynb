-- %%
-- Crear tabla de hechos principal (solo estructura, sin datos)
CREATE OR REPLACE TABLE prueba_api.gold.fact_jobs (
    -- Clave primaria
    job_id STRING,
    
    -- Claves foráneas a dimensiones
    employer_sk BIGINT,
    location_sk BIGINT,
    employment_type_sk BIGINT,
    date_sk BIGINT,
    
    -- Información de la oferta
    job_title STRING,
    job_description STRING,
    job_publisher STRING,
    job_onet_soc STRING,
    job_onet_job_zone STRING,
    
    -- Métricas de modalidad
    job_is_remote BOOLEAN,
    
    -- Métricas salariales
    job_salary DOUBLE,
    job_min_salary DOUBLE,
    job_max_salary DOUBLE,
    job_salary_avg DOUBLE,
    job_salary_period STRING,
    job_salary_string STRING,
    
    -- Fechas
    job_posted_at STRING,
    job_posted_at_timestamp DOUBLE,
    job_posted_at_datetime_utc TIMESTAMP,
    
    -- Aplicación
    job_apply_link STRING,
    job_apply_is_direct BOOLEAN,
    apply_options STRING,
    
    -- Beneficios
    job_benefits STRING,
    
    -- Enlaces
    job_google_link STRING,
    
    -- Metadatos
    processed_at TIMESTAMP,
    fecha_carga TIMESTAMP,
    row_hash STRING NOT NULL
)
COMMENT 'Tabla de hechos principal con todas las ofertas de trabajo y métricas';
