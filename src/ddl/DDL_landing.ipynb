# %%
# %sql
CREATE SCHEMA IF NOT EXISTS prueba_api.landing;
-- ============================================================
-- Crear the Volume para archivos
-- Crear volume tipo MANAGED (Databricks administra el storage)
-- ============================================================

CREATE VOLUME IF NOT EXISTS prueba_api.landing.archivos
COMMENT 'Volume para almacenar archivos CSV crudos';
-- Verificar que se creó
SHOW VOLUMES IN prueba_api.landing;
